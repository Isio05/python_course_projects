# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___
# # Pandas Data Visualization Exercise
#
# This is just a quick exercise for you to review the various plots we showed earlier. Use **df3** to replicate the following plots.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df3 = pd.read_csv('df3')
# %matplotlib inline

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# a    500 non-null float64
# b    500 non-null float64
# c    500 non-null float64
# d    500 non-null float64
# dtypes: float64(4)
# memory usage: 15.7 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %% [markdown]
# ** Recreate this scatter plot of b vs a. Note the color and size of the points. Also note the figure size. See if you can figure out how to stretch it in a similar fashion. Remeber back to your matplotlib lecture...**

# %%
df3.plot(x='a', y='b', kind='scatter', figsize=(8,4), c='red', s=50)

# %% [markdown]
# ** Create a histogram of the 'a' column.**

# %%
df3.plot(y='a', kind='hist')

# %% [markdown]
# ** These plots are okay, but they don't look very polished. Use style sheets to set the style to 'ggplot' and redo the histogram from above. Also figure out how to add more bins to it.***

# %%
plt.style.use('ggplot')

# %%
df3['a'].plot.hist(bins=30)

# %% [markdown]
# ** Create a boxplot comparing the a and b columns.**

# %%
df3.boxplot(column=['a','b'])

# %% [markdown]
# ** Create a kde plot of the 'd' column **

# %%
df3['d'].plot.kde()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-23-7be5390d35d5> in <module>()
# ----> 1 df3['d'].plot.kde()
#
# C:\Anaconda\envs\1_Introduction\lib\site-packages\pandas\plotting\_core.py in kde(self, bw_method, ind, **kwds)
#    2872     })
#    2873     def kde(self, bw_method=None, ind=None, **kwds):
# -> 2874         return self(kind='kde', bw_method=bw_method, ind=ind, **kwds)
#    2875
#    2876     density = kde
#
# C:\Anaconda\envs\1_Introduction\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2739                            colormap=colormap, table=table, yerr=yerr,
#    2740                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2741                            **kwds)
#    2742     __call__.__doc__ = plot_series.__doc__
#    2743
#
# C:\Anaconda\envs\1_Introduction\lib\site-packages\pandas\plotting\_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2000                  yerr=yerr, xerr=xerr,
#    2001                  label=label, secondary_y=secondary_y,
# -> 2002                  **kwds)
#    2003
#    2004
#
# C:\Anaconda\envs\1_Introduction\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1802         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1803
# -> 1804     plot_obj.generate()
#    1805     plot_obj.draw()
#    1806     return plot_obj.result
#
# C:\Anaconda\envs\1_Introduction\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     258         self._compute_plot_data()
#     259         self._setup_subplots()
# --> 260         self._make_plot()
#     261         self._add_table()
#     262         self._make_legend()
#
# C:\Anaconda\envs\1_Introduction\lib\site-packages\pandas\plotting\_core.py in _make_plot(self)
#    1365             kwds = self._make_plot_keywords(kwds, y)
#    1366             artists = self._plot(ax, y, column_num=i,
# -> 1367                                  stacking_id=stacking_id, **kwds)
#    1368             self._add_legend_handle(artists[0], label, index=i)
#    1369
#
# C:\Anaconda\envs\1_Introduction\lib\site-packages\pandas\plotting\_core.py in _plot(cls, ax, y, style, bw_method, ind, column_num, stacking_id, **kwds)
#    1463     def _plot(cls, ax, y, style=None, bw_method=None, ind=None,
#    1464               column_num=None, stacking_id=None, **kwds):
# -> 1465         from scipy.stats import gaussian_kde
#    1466         from scipy import __version__ as spv
#    1467
#
# ModuleNotFoundError: No module named 'scipy'

# %% [markdown]
# ** Figure out how to increase the linewidth and make the linestyle dashed. (Note: You would usually not dash a kde plot line)**

# %% [markdown]
# ** Create an area plot of all the columns for just the rows up to 30. (hint: use .ix).**

# %%
df3.loc[1:30].plot.area()

# %% [markdown]
# ## Bonus Challenge!
# Note, you may find this really hard, reference the solutions if you can't figure it out!
# ** Notice how the legend in our previous figure overlapped some of actual diagram. Can you figure out how to display the legend outside of the plot as shown below?**
#
# ** Try searching Google for a good stackoverflow link on this topic. If you can't find it on your own - [use this one for a hint.](http://stackoverflow.com/questions/23556153/how-to-put-legend-outside-the-plot-with-pandas)**

# %%
fig = plt.figure()
df3.loc[1:30].plot.area()
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %% [markdown]
# # Great Job!
